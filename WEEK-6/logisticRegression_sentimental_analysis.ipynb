# %% [markdown]
# <a href="https://colab.research.google.com/github/ABB-4101/2025-26_AI-B-DS_4101-Abdulrahman/blob/main/WEEK-6/logisticRegression_sentimental_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LogisticRegression
data = pd.DataFrame({
    'text': ['I love this', 'This is great', 'I hate this', 'This is bad'],
    'label': [1, 1, 0, 0]
})

vectorizer = CountVectorizer()
X = vectorizer.fit_transform(data['text'])
y = data['label']
model = LogisticRegression()
model.fit(X, y)
test = ["I love it"]
pred = model.predict(vectorizer.transform(test))
print("Positive" if pred[0] == 1 else "Negative")
# Out:
# Positive
