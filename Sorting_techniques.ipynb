# %% [markdown]
# <a href="https://colab.research.google.com/github/ABB-4101/2025-26_AI-B-DS_4101-Abdulrahman/blob/main/Sorting_techniques.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#bubble sort
n=int(input("Enter no. of elemnts"))
arr=[]
for i in range(n):
  arr.append(int(input(f"Enter element {i+1}: ")))
print("\n Original ARRay :", arr)
for i in range(n-1):
  for j in range(n-1-i):
    if arr[j]>arr[j+1]:
      arr[j],arr[j+1]=arr[j+1],arr[j]
print("Sorted Array: ",arr)
# Out:
# Enter no. of elemnts3
# Enter element 1: 32
# Enter element 2: 12
# Enter element 3: 23
#
#  Original ARRay : [32, 12, 23]
# Sorted Array:  [12, 23, 32]

# %%
#Selection sort
n=int(input("Enter no. of elements: "))
arr=[]
for i in range(n):
  arr.append(int(input(f"Enter element{i+1}:")))
print("\nOriginal Array: ", arr)
for i in range(n-1):
  min_index=i
  for j in range(i+1,n):
    if arr[j]<arr[min_index]:
      min_index=j
  arr[i],arr[min_index]=arr[min_index],arr[i]
print("Sorted array: ",arr)
# Out:
# Enter no. of elements: 5
# Enter element1:23
# Enter element2:21
# Enter element3:3
# Enter element4:3
# Enter element5:54
#
# Original Array:  [23, 21, 3, 3, 54]
# Sorted array:  [3, 3, 21, 23, 54]
