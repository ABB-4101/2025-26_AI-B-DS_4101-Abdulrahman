# %% [markdown]
# <a href="https://colab.research.google.com/github/ABB-4101/2025-26_AI-B-DS_4101-Abdulrahman/blob/main/selection_sort.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Selection sort
n=int(input("Enter no. of elements: "))
arr=[]
for i in range(n):
  arr.append(int(input(f"Enter element{i+1}:")))
print("\nOriginal Array: ", arr)
for i in range(n-1):
  min_index=i
  for j in range(i+1,n):
    if arr[j]<arr[min_index]:
      min_index=j
  arr[i],arr[min_index]=arr[min_index],arr[i]
print("Sorted array: ",arr)
# Out:
# Enter no. of elements: 5
# Enter element1:21
# Enter element2:34
# Enter element3:23
# Enter element4:22
# Enter element5:11
#
# Original Array:  [21, 34, 23, 22, 11]
# Sorted array:  [11, 21, 22, 23, 34]
